# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df1 = df.loc[df['species'] == "Iris-setosa"]
df1
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
total_count = np.count_nonzero(df1.sepal_length)
total_count
# Out:
# 50

# %%
temp = df1.sepal_length.unique()
temp
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3])

# %%
frequency = []
probability = []
count = 0

for i in temp:
    for j in df1["sepal_length"]:
        if i == j:
            count += 1
    frequency.append(count)
    probability.append(count/total_count)
    count = 0
    
print(temp)
print(frequency)
print(probability)
# Out:
# [5.1 4.9 4.7 4.6 5.  5.4 4.4 4.8 4.3 5.8 5.7 5.2 5.5 4.5 5.3]
# [8, 4, 2, 4, 8, 5, 3, 5, 1, 1, 2, 3, 2, 1, 1]
# [0.16, 0.08, 0.04, 0.08, 0.16, 0.1, 0.06, 0.1, 0.02, 0.02, 0.04, 0.06, 0.04, 0.02, 0.02]

# %%
df2 = pd.DataFrame({'Sepal Length' : temp, 'Frequency' : frequency, 'Probability' : probability})
df2
# Out:
#     Sepal Length  Frequency  Probability
# 0            5.1          8         0.16
# 1            4.9          4         0.08
# 2            4.7          2         0.04
# 3            4.6          4         0.08
# 4            5.0          8         0.16
# 5            5.4          5         0.10
# 6            4.4          3         0.06
# 7            4.8          5         0.10
# 8            4.3          1         0.02
# 9            5.8          1         0.02
# 10           5.7          2         0.04
# 11           5.2          3         0.06
# 12           5.5          2         0.04
# 13           4.5          1         0.02
# 14           5.3          1         0.02

# %%
expect_value = 0
i = 0
for value in temp:
    expect_value += (value * probability[i])
    i += 1
print('Expected Value =', expect_value)
# Out:
# Expected Value = 5.005999999999999
